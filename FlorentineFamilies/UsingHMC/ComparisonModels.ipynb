# %% [markdown]
# # Latent space model for Networks: $\mathbb{R}^2$, $\mathbb{R}^3$, $\mathbb{S}^1$ and $\mathbb{S}^2$
# ## Florentine families

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from Modules.EuclideanM import *
from Modules.EuclideanV import *
from Modules.EuclideanC import *
from Modules.SphericalM import *
from Modules.SphericalV import *
from Modules.SphericalC import *

# %% [markdown]
# ## Model

# %% [markdown]
# Table of degree of freedom, generalized linear model, distance o simmilarity

# %%
samples, Hamiltonian_p, LogL, acep_rate_history = load_results(filename="FlorentineS1.xlsx", N_samples=25000, N_nodes=15, D=2)
#samples_Z, samples_a = samples 
samples_Z, samples_a, samples_b = samples
# Out:
# Loading samples...
# Loading diagnostics...
# Done.

# %%
plot_alpha(np.mod(np.arctan2(samples_Z[:, 1, 1], samples_Z[:, 1, 0]), 2*np.pi))

# %% [markdown]
# ## Point estimators: ML, MAP, CM

# %% [markdown]
# ## Posterior predictive checking

# %% [markdown]
# ## Model comparison criteria

# %% [markdown]
# ## Sociomatrix

# %% [markdown]
# ## Prediction evaluation
